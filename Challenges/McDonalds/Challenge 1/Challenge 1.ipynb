# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('menu.csv')
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df.isnull().any()
# Out:
# Category                         False
# Item                             False
# Serving Size                     False
# Calories                         False
# Calories from Fat                False
# Total Fat                        False
# Total Fat (% Daily Value)        False
# Saturated Fat                    False
# Saturated Fat (% Daily Value)    False
# Trans Fat                        False
# Cholesterol                      False
# Cholesterol (% Daily Value)      False
# Sodium                           False
# Sodium (% Daily Value)           False
# Carbohydrates                    False
# Carbohydrates (% Daily Value)    False
# Dietary Fiber                    False
# Dietary Fiber (% Daily Value)    False
# Sugars                           False
# Protein                          False
# Vitamin A (% Daily Value)        False
# Vitamin C (% Daily Value)        False
# Calcium (% Daily Value)          False
# Iron (% Daily Value)             False
# dtype: bool

# %%
df.shape
# Out:
# (260, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
df.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
df['Calories'].describe()
# Out:
# count     260.000000
# mean      368.269231
# std       240.269886
# min         0.000000
# 25%       210.000000
# 50%       340.000000
# 75%       500.000000
# max      1880.000000
# Name: Calories, dtype: float64

# %%
df_gptest2 = df[['Category','Calories']]
grouped_test_Category = df_gptest2.groupby(['Category'],as_index= False).mean()
grouped_test_Category
# Out:
#              Category    Calories
# 0         Beef & Pork  494.000000
# 1           Beverages  113.703704
# 2           Breakfast  526.666667
# 3      Chicken & Fish  552.962963
# 4        Coffee & Tea  283.894737
# 5            Desserts  222.142857
# 6              Salads  270.000000
# 7  Smoothies & Shakes  531.428571
# 8      Snacks & Sides  245.769231

# %%
df_gptest2 = df[['Category','Calories']]
grouped_test_Category = df_gptest2.groupby(['Category'],as_index= True).mean()
grouped_test_Category
# Out:
#                       Calories
# Category
# Beef & Pork         494.000000
# Beverages           113.703704
# Breakfast           526.666667
# Chicken & Fish      552.962963
# Coffee & Tea        283.894737
# Desserts            222.142857
# Salads              270.000000
# Smoothies & Shakes  531.428571
# Snacks & Sides      245.769231

# %%
df_gptest2 = df[['Category','Calories']]
grouped_test_Category = df_gptest2.groupby(['Category'],as_index= True).mean()
grouped_test_Category

grouped_test_Category.plot(kind='bar', figsize=(10, 10))

plt.xlabel('Categories') # add to x-label to the plot
plt.ylabel('Average') # add y-label to the plot
plt.title("Mc Donald's Categories from Calories") # add title to the plot

plt.show()

# %%
#Pie Chart untuk setiap kategori

df['Total'] = df['Calories'].sum()
df_category
# Out:
# Text(0.5, 1.0, 'Menu McDonalds Berdasarkan Kategori')

# %%
df4=pd.DataFrame(df.iloc[[57,58],1:])
df4
# Out:
#                                         Item    Serving Size  Calories  \
# 57   Premium Crispy Chicken Classic Sandwich  7.5 oz (213 g)       510
# 58  Premium Grilled Chicken Classic Sandwich    7 oz (200 g)       350
#
#     Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 57                200       22.0                         33            3.5
# 58                 80        9.0                         13            2.0
#
#     Saturated Fat (% Daily Value)  Trans Fat  Cholesterol  ...  Carbohydrates  \
# 57                             18        0.0           45  ...             55
# 58                              9        0.0           65  ...             42
#
#     Carbohydrates (% Daily Value)  Dietary Fiber  \
# 57                             18              3
# 58                             14              3
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# ...

# %%
df5=pd.DataFrame(df.iloc[[3,4],1:])
df5
# Out:
#                                Item    Serving Size  Calories  \
# 3         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  Cholesterol  ...  \
# 3                             52        0.0          285  ...
# 4                             42        0.0           50  ...
#
#    Carbohydrates (% Daily Value)  Dietary Fiber  \
# 3                             10              4
# 4                             10              4
#
#    Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 3                             17       2       21                         15
# ...

# %%
df_group_Sandwich1 = df[['Item','Total Fat (% Daily Value)','Carbohydrates (% Daily Value)','Dietary Fiber (% Daily Value)','Calcium (% Daily Value)','Iron (% Daily Value)','Vitamin C (% Daily Value)','Sodium (% Daily Value)','Vitamin A (% Daily Value)']]
df_group_Sandwich1 = df_group_Sandwich1.iloc[57:66:2,:]
df_group_Sandwich1
# Out:
#                                          Item  Total Fat (% Daily Value)  \
# 57    Premium Crispy Chicken Classic Sandwich                         33
# 59       Premium Crispy Chicken Club Sandwich                         51
# 61  Premium Crispy Chicken Ranch BLT Sandwich                         43
# 63    Bacon Clubhouse Crispy Chicken Sandwich                         59
# 65     Southern Style Crispy Chicken Sandwich                         29
#
#     Carbohydrates (% Daily Value)  Dietary Fiber (% Daily Value)  \
# 57                             18                             13
# 59                             19                             14
# 61                             19                             13
# 63                             22                             15
# 65                             14                              7
#
#     Calcium (% Daily Value)  Iron (% Daily Value)  Vitamin C (% Daily Value)  \
# ...

# %%
df_group_Sandwich2 = df[['Item','Total Fat (% Daily Value)','Carbohydrates (% Daily Value)','Dietary Fiber (% Daily Value)','Calcium (% Daily Value)','Iron (% Daily Value)','Vitamin C (% Daily Value)','Sodium (% Daily Value)','Vitamin A (% Daily Value)']]
df_group_Sandwich2 = df_group_Sandwich2.iloc[58:66:2,:]
df_group_Sandwich2
# Out:
#                                           Item  Total Fat (% Daily Value)  \
# 58    Premium Grilled Chicken Classic Sandwich                         13
# 60       Premium Grilled Chicken Club Sandwich                         31
# 62  Premium Grilled Chicken Ranch BLT Sandwich                         23
# 64    Bacon Clubhouse Grilled Chicken Sandwich                         39
#
#     Carbohydrates (% Daily Value)  Dietary Fiber (% Daily Value)  \
# 58                             14                             13
# 60                             15                             13
# 62                             14                             13
# 64                             17                             15
#
#     Calcium (% Daily Value)  Iron (% Daily Value)  Vitamin C (% Daily Value)  \
# 58                       15                    20                          8
# 60                       30                    20                         20
# ...

# %%
average_grilled_sandwich = df_group_Sandwich2.mean()
average_grilled_sandwich

average_grilled_sandwich.plot(kind='bar', figsize=(10, 7))

plt.xlabel('Daily Value/Nutrition') # add to x-label
plt.ylabel('Average')
plt.title('McDonalds Daily Nutrition Average for Order Grilled Sandwich')
# Out:
# Text(0.5, 1.0, 'McDonalds Daily Nutrition Average for Order Grilled Sandwich')

# %%
average_crispy_sandwich = df_group_Sandwich1.mean()
average_crispy_sandwich

average_crispy_sandwich.plot(kind='bar', figsize=(10, 7))

plt.xlabel('Daily Value/Nutrition') # add to x-label
plt.ylabel('Average')
plt.title('McDonalds Daily Nutrition Average for Order Crispy Sandwich')
# Out:
# Text(0.5, 1.0, 'McDonalds Daily Nutrition Average for Order Crispy Sandwich')

# %%
df_nutritional=pd.DataFrame(df.iloc[[38,48,78,84,100,101,106,132,208,235], [1,3]])
df_nutritional
# Out:
#                                                   Item  Calories
# 38                                          Hash Brown       150
# 48                                           Hamburger       240
# 78                         Chicken McNuggets (4 piece)       190
# 84         Premium Bacon Ranch Salad (without Chicken)       140
# 100                                         Side Salad        20
# 101                                       Apple Slices        15
# 106                                Kids Ice Cream Cone        45
# 132                   Minute Maid 100% Apple Juice Box        80
# 208  Iced Coffee with Sugar Free French Vanilla Syr...        80
# 235                 Strawberry Banana Smoothie (Small)       210

# %%
z=0
while z <9:
    print("Counting minimum amounts of", df_nutritional.iloc[z,0] ,"to fulfill one day's nutritional requirements\n")

    a=df_nutritional.iloc[z,1]
    i=0

    while a<2201:
        a=a+df_nutritional.iloc[z,1]
        i=i+1   
        print("It took",i+1 ,"Items of",df_nutritional.iloc[z,0]+"\n")
        
    z+=1
    print("\n")
# Out:
# Counting minimum amounts of Hash Brown to fulfill one day's nutritional requirements
#
# It took 2 Items of Hash Brown
#
# It took 3 Items of Hash Brown
#
# It took 4 Items of Hash Brown
#
# It took 5 Items of Hash Brown
#
# It took 6 Items of Hash Brown
#
# It took 7 Items of Hash Brown
#
# It took 8 Items of Hash Brown
#
# It took 9 Items of Hash Brown
#
# It took 10 Items of Hash Brown
#
# It took 11 Items of Hash Brown
#
# It took 12 Items of Hash Brown
#
# It took 13 Items of Hash Brown
#
# It took 14 Items of Hash Brown
#
# It took 15 Items of Hash Brown
#
#
#
# Counting minimum amounts of Hamburger to fulfill one day's nutritional requirements
#
# It took 2 Items of Hamburger
#
# It took 3 Items of Hamburger
#
# It took 4 Items of Hamburger
#
# It took 5 Items of Hamburger
#
# It took 6 Items of Hamburger
#
# It took 7 Items of Hamburger
#
# It took 8 Items of Hamburger
#
# It took 9 Items of Hamburger
#
# It took 10 Items of Hamburger
#
#
#
# ...

# %%
import matplotlib.pyplot as plot
fig = plot.figure()
ax = fig.add_axes([0,0,1,1])
t = [df_nutritional.iloc[0,0], df_nutritional.iloc[1,0], df_nutritional.iloc[2,0], df_nutritional.iloc[3,0], df_nutritional.iloc[4,0], df_nutritional.iloc[5,0], df_nutritional.iloc[6,0], df_nutritional.iloc[7,0], df_nutritional.iloc[8,0],]
s = [15,10,12,16,147,49,28,28,11]

ax.tick_params(axis='both', which='major', labelsize=12)
ax.barh(t,s)
plot.show()

# %%
dfc=pd.DataFrame(s,t)
dfc.columns=["Amount"]
dfc
# Out:
#                                                     Amount
# Hash Brown                                              15
# Hamburger                                               10
# Chicken McNuggets (4 piece)                             12
# Premium Bacon Ranch Salad (without Chicken)             16
# Apple Slices                                           147
# Kids Ice Cream Cone                                     49
# Minute Maid 100% Apple Juice Box                        28
# Iced Coffee with Sugar Free French Vanilla Syru...      28
# Strawberry Banana Smoothie (Small)                      11

# %%
df.query('Item.str.contains("Egg White")', engine='python')
# Out:
#      Category                                               Item  \
# 1   Breakfast                                  Egg White Delight
# 4   Breakfast                   Sausage McMuffin with Egg Whites
# 8   Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9   Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# 14  Breakfast  Sausage Biscuit with Egg Whites (Regular Biscuit)
# 15  Breakfast    Sausage Biscuit with Egg Whites (Large Biscuit)
# 20  Breakfast     Bacon, Egg & Cheese McGriddles with Egg Whites
# 23  Breakfast   Sausage, Egg & Cheese McGriddles with Egg Whites
# 25  Breakfast          Bacon, Egg & Cheese Bagel with Egg Whites
# 29  Breakfast    Big Breakfast with Egg Whites (Regular Biscuit)
# 30  Breakfast      Big Breakfast with Egg Whites (Large Biscuit)
# 33  Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# 34  Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
#
# ...
